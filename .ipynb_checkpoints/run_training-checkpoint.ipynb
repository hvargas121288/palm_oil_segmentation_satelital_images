# %%
# image segmentation
import os
import gc
import random
import utils
import numpy as np
import tifffile as tif
import tensorflow as tf
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

from model import simple_unet

np.set_printoptions(precision = 2)
np.set_printoptions(suppress  = True)

# %%
gpus = tf.config.list_physical_devices('GPU')
if gpus:
  # Restrict TensorFlow to only allocate 1GB of memory on the first GPU
  try:
    tf.config.set_logical_device_configuration(
        gpus[0],
        [tf.config.LogicalDeviceConfiguration(memory_limit=3072)])
    logical_gpus = tf.config.list_logical_devices('GPU')
    print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
  except RuntimeError as e:
    # Virtual devices must be set before GPUs have been initialized
    print(e)
# Out:
# 1 Physical GPUs, 1 Logical GPUs

# %%
img  = tif.imread('data/multi_recorte_1.tif')
mask = mpimg.imread('data/multi_recorte_1.png')[:,:,0]
mask = utils.convert_8bits(mask)

images_path = 'images/'
masks_path  = 'masks/'

# %%
utils.remove_files('images')
utils.remove_files('masks')
# Out:
# Todos los archivos en images han sido eliminados.
# Todos los archivos en masks han sido eliminados.

# %%
# Parameters
Nx, Ny, Nz = img.shape
Nw   = 256
step = 100

# Index images
indx_x = np.unique(np.concatenate(([np.arange(0, Nx-Nw, step)], [np.array([Nx-Nw])]), axis = 1))
indx_y = np.unique(np.concatenate(([np.arange(0, Ny-Nw, step)], [np.array([Ny-Nw])]), axis = 1))

# Total images
N      = indx_x.size*indx_y.size

# Cut images and save them
cntr   = 0
X_test = np.zeros((N, Nw, Nw, Nz))
for i in indx_x:
    for j in indx_y:
        cntr  += 1
        i_idx = np.arange(i, i+Nw)
        j_idx = np.arange(j, j+Nw)
        img_block = img[i_idx[:, None], j_idx[None, :], :]
        img_block = utils.convert_8bits(img_block)
        mask_block = mask[i_idx[:, None], j_idx[None, :]]
        plt.imsave(images_path + str(cntr) +'.png', img_block) 
        plt.imsave(masks_path + str(cntr) +'.png', mask_block, cmap = 'gray')

# %%
images_paths = sorted(
    [os.path.join(images_path, fname)
     for fname in os.listdir(images_path)
     if fname.endswith(".png")]
)

masks_paths = sorted(
    [os.path.join(masks_path, fname)
     for fname in os.listdir(masks_path)
     if fname.endswith(".png") and not fname.startswith(".")]
)

train_images_paths = images_paths
train_masks_paths  = masks_paths

img_height    = 256
img_width     = 256
img_channels  = 3

# %%
X_train = np.zeros((len(train_images_paths), img_height, img_width, img_channels), dtype= 'float32')
Y_train = np.zeros((len(train_masks_paths), img_height, img_width, 1), dtype = np.bool_)

for i in range(len(train_images_paths)):   
    img = mpimg.imread(train_images_paths[i])[:,:,:img_channels] 
    img = utils.normalize(img)
    X_train[i] = img  #Fill empty X_train with values from img

    
for i in range(len(train_masks_paths)):   
    img = mpimg.imread(train_masks_paths[i])[:,:,0] 
    img = (img > np.max(np.unique(img))/2).astype(np.bool_)
    img = np.expand_dims(img, axis=2)
    Y_train[i] = img  #Fill empty Y_train with values from img 


# Show trainning images
fig, axs = plt.subplots(2,2, figsize = (10, 6))

h1 = axs[0, 0].imshow(X_train[0])
plt.colorbar(h1, ax = axs[0, 0])
axs[0, 0].axis('off')

h2 = axs[0, 1].imshow(Y_train[0], cmap = 'gray')
plt.colorbar(h2, ax = axs[0, 1])
axs[0, 1].axis('off')


h3 = axs[1, 0].imshow(X_train[1])
plt.colorbar(h3, ax = axs[1, 0])
axs[1, 0].axis('off')

h4 = axs[1, 1].imshow(Y_train[1], cmap = 'gray')
plt.colorbar(h4, ax = axs[1, 1])
axs[1, 1].axis('off')


fig.tight_layout()
plt.show()

# %%
model = simple_unet((img_height, img_width, img_channels), n_filt = 4)
optimizer = tf.keras.optimizers.Adam(learning_rate = 0.0001)
model.compile(optimizer = optimizer, loss='binary_crossentropy', metrics=['accuracy'])

# %%
#callbacks
#with tf.device('/cpu:0'):
results = model.fit(X_train, Y_train,
                                 validation_split = 0.1,
                                 epochs           = 150)


model.save('model_segmentation.keras')

tf.keras.backend.clear_session()
gc.collect()
# Out:
# Epoch 1/150
# 12/12 [==============================] - 4s 288ms/step - loss: 0.6271 - accuracy: 0.8979 - val_loss: 0.6189 - val_accuracy: 0.9431
# Epoch 2/150
# 12/12 [==============================] - 3s 276ms/step - loss: 0.6267 - accuracy: 0.8979 - val_loss: 0.6184 - val_accuracy: 0.9431
# Epoch 3/150
# 12/12 [==============================] - 3s 276ms/step - loss: 0.6263 - accuracy: 0.8979 - val_loss: 0.6180 - val_accuracy: 0.9431
# Epoch 4/150
# 12/12 [==============================] - 3s 276ms/step - loss: 0.6259 - accuracy: 0.8979 - val_loss: 0.6175 - val_accuracy: 0.9431
# Epoch 5/150
# 12/12 [==============================] - 3s 277ms/step - loss: 0.6254 - accuracy: 0.8979 - val_loss: 0.6170 - val_accuracy: 0.9431
# Epoch 6/150
# 12/12 [==============================] - 3s 275ms/step - loss: 0.6250 - accuracy: 0.8979 - val_loss: 0.6166 - val_accuracy: 0.9431
# Epoch 7/150
# 12/12 [==============================] - 3s 277ms/step - loss: 0.6246 - accuracy: 0.8979 - val_loss: 0.6161 - val_accuracy: 0.9431
# Epoch 8/150
# 12/12 [==============================] - 3s 278ms/step - loss: 0.6242 - accuracy: 0.8979 - val_loss: 0.6157 - val_accuracy: 0.9431
# Epoch 9/150
# 12/12 [==============================] - 3s 277ms/step - loss: 0.6238 - accuracy: 0.8979 - val_loss: 0.6152 - val_accuracy: 0.9431
# Epoch 10/150
# 12/12 [==============================] - 3s 277ms/step - loss: 0.6234 - accuracy: 0.8979 - val_loss: 0.6148 - val_accuracy: 0.9431
# Epoch 11/150
# 12/12 [==============================] - 3s 278ms/step - loss: 0.6230 - accuracy: 0.8979 - val_loss: 0.6143 - val_accuracy: 0.9431
# Epoch 12/150
# 12/12 [==============================] - 3s 277ms/step - loss: 0.6226 - accuracy: 0.8979 - val_loss: 0.6139 - val_accuracy: 0.9431
# Epoch 13/150
# 12/12 [==============================] - 3s 277ms/step - loss: 0.6222 - accuracy: 0.8979 - val_loss: 0.6134 - val_accuracy: 0.9431
# Epoch 14/150
# 12/12 [==============================] - 3s 277ms/step - loss: 0.6218 - accuracy: 0.8979 - val_loss: 0.6129 - val_accuracy: 0.9431
# Epoch 15/150
# 12/12 [==============================] - 3s 278ms/step - loss: 0.6214 - accuracy: 0.8979 - val_loss: 0.6125 - val_accuracy: 0.9431
# Epoch 16/150
# 12/12 [==============================] - 3s 277ms/step - loss: 0.6210 - accuracy: 0.8979 - val_loss: 0.6120 - val_accuracy: 0.9431
# Epoch 17/150
# 12/12 [==============================] - 3s 276ms/step - loss: 0.6206 - accuracy: 0.8979 - val_loss: 0.6116 - val_accuracy: 0.9431
# Epoch 18/150
# Epoch 59/150
# 12/12 [==============================] - 3s 277ms/step - loss: 0.6041 - accuracy: 0.8979 - val_loss: 0.5930 - val_accuracy: 0.9431
# Epoch 60/150
# 12/12 [==============================] - 3s 277ms/step - loss: 0.6038 - accuracy: 0.8979 - val_loss: 0.5925 - val_accuracy: 0.9431
# Epoch 61/150
# 12/12 [==============================] - 3s 276ms/step - loss: 0.6034 - accuracy: 0.8979 - val_loss: 0.5921 - val_accuracy: 0.9431
# Epoch 62/150
# 12/12 [==============================] - 3s 277ms/step - loss: 0.6030 - accuracy: 0.8979 - val_loss: 0.5917 - val_accuracy: 0.9431
# Epoch 63/150
# 12/12 [==============================] - 3s 277ms/step - loss: 0.6026 - accuracy: 0.8979 - val_loss: 0.5912 - val_accuracy: 0.9431
# Epoch 64/150
# 12/12 [==============================] - 3s 277ms/step - loss: 0.6022 - accuracy: 0.8979 - val_loss: 0.5908 - val_accuracy: 0.9431
# Epoch 65/150
# 12/12 [==============================] - 3s 276ms/step - loss: 0.6018 - accuracy: 0.8979 - val_loss: 0.5904 - val_accuracy: 0.9431
# Epoch 66/150
# 12/12 [==============================] - 3s 277ms/step - loss: 0.6015 - accuracy: 0.8979 - val_loss: 0.5899 - val_accuracy: 0.9431
# Epoch 67/150
# 12/12 [==============================] - 3s 277ms/step - loss: 0.6011 - accuracy: 0.8979 - val_loss: 0.5895 - val_accuracy: 0.9431
# Epoch 68/150
# 12/12 [==============================] - 3s 276ms/step - loss: 0.6007 - accuracy: 0.8979 - val_loss: 0.5891 - val_accuracy: 0.9431
# Epoch 69/150
# 12/12 [==============================] - 3s 277ms/step - loss: 0.6003 - accuracy: 0.8979 - val_loss: 0.5886 - val_accuracy: 0.9431
# Epoch 70/150
# 12/12 [==============================] - 3s 277ms/step - loss: 0.5999 - accuracy: 0.8979 - val_loss: 0.5882 - val_accuracy: 0.9431
# Epoch 71/150
# 12/12 [==============================] - 3s 277ms/step - loss: 0.5996 - accuracy: 0.8979 - val_loss: 0.5878 - val_accuracy: 0.9431
# Epoch 72/150
# 12/12 [==============================] - 3s 283ms/step - loss: 0.5992 - accuracy: 0.8979 - val_loss: 0.5873 - val_accuracy: 0.9431
# Epoch 73/150
# 12/12 [==============================] - 3s 276ms/step - loss: 0.5988 - accuracy: 0.8979 - val_loss: 0.5869 - val_accuracy: 0.9431
# Epoch 74/150
#  7/12 [================>.............] - ETA: 1s - loss: 0.5983 - accuracy: 0.8986
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 3
#       1 #callbacks
#       2 #with tf.device('/cpu:0'):
# ----> 3 results = model.fit(X_train, Y_train,
#       4                                  validation_split = 0.1,
#       5                                  epochs           = 150)
#       8 model.save('model_segmentation.keras')
#      10 tf.keras.backend.clear_session()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\engine\training.py:1570, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1568 logs = tmp_logs
#    1569 end_step = step + data_handler.step_increment
# -> 1570 callbacks.on_train_batch_end(end_step, logs)
#    1571 if self.stop_training:
#    1572     break
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\callbacks.py:470, in CallbackList.on_train_batch_end(self, batch, logs)
#     463 """Calls the `on_train_batch_end` methods of its callbacks.
#     464
#     465 Args:
#     466     batch: Integer, index of batch within the current epoch.
#     467     logs: Dict. Aggregated metric results up until this batch.
#     468 """
#     469 if self._should_call_train_batch_hooks:
# --> 470     self._call_batch_hook(ModeKeys.TRAIN, "end", batch, logs=logs)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\callbacks.py:317, in CallbackList._call_batch_hook(self, mode, hook, batch, logs)
#     315     self._call_batch_begin_hook(mode, batch, logs)
#     316 elif hook == "end":
# --> 317     self._call_batch_end_hook(mode, batch, logs)
#     318 else:
#     319     raise ValueError(
#     320         f"Unrecognized hook: {hook}. "
#     321         'Expected values are ["begin", "end"]'
#     322     )
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\callbacks.py:340, in CallbackList._call_batch_end_hook(self, mode, batch, logs)
#     337     batch_time = time.time() - self._batch_start_time
#     338     self._batch_times.append(batch_time)
# --> 340 self._call_batch_hook_helper(hook_name, batch, logs)
#     342 if len(self._batch_times) >= self._num_batches_for_timing_check:
#     343     end_hook_name = hook_name
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\callbacks.py:388, in CallbackList._call_batch_hook_helper(self, hook_name, batch, logs)
#     386 for callback in self.callbacks:
#     387     hook = getattr(callback, hook_name)
# --> 388     hook(batch, logs)
#     390 if self._check_timing:
#     391     if hook_name not in self._hook_times:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\callbacks.py:1081, in ProgbarLogger.on_train_batch_end(self, batch, logs)
#    1080 def on_train_batch_end(self, batch, logs=None):
# -> 1081     self._batch_update_progbar(batch, logs)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\callbacks.py:1157, in ProgbarLogger._batch_update_progbar(self, batch, logs)
#    1153     self.seen += add_seen
#    1155 if self.verbose == 1:
#    1156     # Only block async when verbose = 1.
# -> 1157     logs = tf_utils.sync_to_numpy_or_python_type(logs)
#    1158     self.progbar.update(self.seen, list(logs.items()), finalize=False)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\utils\tf_utils.py:635, in sync_to_numpy_or_python_type(tensors)
#     632         return t
#     633     return t.item() if np.ndim(t) == 0 else t
# --> 635 return tf.nest.map_structure(_to_single_numpy_or_python_type, tensors)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\util\nest.py:917, in map_structure(func, *structure, **kwargs)
#     913 flat_structure = (flatten(s, expand_composites) for s in structure)
#     914 entries = zip(*flat_structure)
#     916 return pack_sequence_as(
# --> 917     structure[0], [func(*x) for x in entries],
#     918     expand_composites=expand_composites)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\util\nest.py:917, in <listcomp>(.0)
#     913 flat_structure = (flatten(s, expand_composites) for s in structure)
#     914 entries = zip(*flat_structure)
#     916 return pack_sequence_as(
# --> 917     structure[0], [func(*x) for x in entries],
#     918     expand_composites=expand_composites)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\utils\tf_utils.py:628, in sync_to_numpy_or_python_type.<locals>._to_single_numpy_or_python_type(t)
#     625 def _to_single_numpy_or_python_type(t):
#     626     # Don't turn ragged or sparse tensors to NumPy.
#     627     if isinstance(t, tf.Tensor):
# --> 628         t = t.numpy()
#     629     # Strings, ragged and sparse tensors don't have .item(). Return them
#     630     # as-is.
#     631     if not isinstance(t, (np.ndarray, np.generic)):
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\framework\ops.py:1157, in _EagerTensorBase.numpy(self)
#    1134 """Copy of the contents of this Tensor into a NumPy array or scalar.
#    1135
#    1136 Unlike NumPy arrays, Tensors are immutable, so this method has to copy
#    (...)
#    1154     NumPy dtype.
#    1155 """
#    1156 # TODO(slebedev): Consider avoiding a copy for non-CPU or remote tensors.
# -> 1157 maybe_arr = self._numpy()  # pylint: disable=protected-access
#    1158 return maybe_arr.copy() if isinstance(maybe_arr, np.ndarray) else maybe_arr
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\framework\ops.py:1123, in _EagerTensorBase._numpy(self)
#    1121 def _numpy(self):
#    1122   try:
# -> 1123     return self._numpy_internal()
#    1124   except core._NotOkStatusException as e:  # pylint: disable=protected-access
#    1125     raise core._status_to_exception(e) from None
#
# KeyboardInterrupt:

# %%
plt.figure(figsize=(12,6))
plt.semilogy(results.history['loss'], label = 'Loss')
plt.semilogy(results.history['val_loss'], label = 'Val Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss Function')
plt.legend()
plt.grid('on')
plt.show()
